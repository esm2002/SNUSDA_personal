# %%
import pickle
import cv2
import numpy as np

# %%
file_path = 'newdata318.pickle'

# %%
with open('newdata300.pickle', "rb") as file:
    data1 = pickle.load(file)
with open('newdata301.pickle', "rb") as file:
    data2 = pickle.load(file)
with open('newdata302.pickle', "rb") as file:
    data3 = pickle.load(file)
with open('newdata303.pickle', "rb") as file:
    data4 = pickle.load(file)
with open('newdata304.pickle', "rb") as file:
    data5 = pickle.load(file)
with open('newdata305.pickle', "rb") as file:
    data6 = pickle.load(file)
with open('newdata306.pickle', "rb") as file:
    data7 = pickle.load(file)
with open('newdata307.pickle', "rb") as file:
    data8 = pickle.load(file)
with open('newdata308.pickle', "rb") as file:
    data9 = pickle.load(file)
with open('newdata309.pickle', "rb") as file:
    data10 = pickle.load(file)
with open('newdata310.pickle', "rb") as file:
    data11 = pickle.load(file)
with open('newdata311.pickle', "rb") as file:
    data12 = pickle.load(file)
with open('newdata312.pickle', "rb") as file:
    data13 = pickle.load(file)
with open('newdata313.pickle', "rb") as file:
    data14 = pickle.load(file)
with open('newdata314.pickle', "rb") as file:
    data15 = pickle.load(file)
with open('newdata315.pickle', "rb") as file:
    data16 = pickle.load(file)
with open('newdata316.pickle', "rb") as file:
    data17 = pickle.load(file)
with open('newdata317.pickle', "rb") as file:
    data18 = pickle.load(file)
with open('newdata318.pickle', "rb") as file:
    data19 = pickle.load(file)

# %%
images = data1[1] + data2[1] + data3[1] + data4[1] + data5[1] + data6[1] + data7[1] + data8[1] + data9[1] + data10[1] + data11[1] + data12[1] + data13[1] + data14[1] + data15[1] + data16[1] + data17[1] + data18[1] + data19[1]
labels = data1[0] + data2[0] + data3[0] + data4[0] + data5[0] + data6[0] + data7[0] + data8[0] + data9[0] + data10[0] + data11[0] + data12[0] + data13[0] + data14[0] + data15[0] + data16[0] + data17[0] + data18[0] + data19[0]

# %%
total = [labels , images]

# %%
print(total)
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
with open("total_ss.pickle", "wb") as file:
                pickle.dump(total, file)

# %%
with open('total_ss.pickle', "rb") as file:
    data = pickle.load(file)

# %%
print(data[1])
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
